# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

# %%
df= pd.read_csv(r"D:\1_ML\Machine-Learning-\Linear Regression\1_Basics\Experience-Salary.csv")

# %%
df.head() # give us a snapshot of data set from biginning

# %%
df.shape # it will show total datap points (1000) and feature (2)

# %%
df.columns  # gives us columns names from dataset

# %%
df.info()  # give overall idea of dataset

# %%
df.describe()  # give us a summary of the dataset

# %%
plt.scatter(df['exp(in months)'],df['salary(in thousands)'],color='black',alpha=0.5)
plt.xlabel("Months ")
plt.ylabel("Expenditure ")
plt.show()
